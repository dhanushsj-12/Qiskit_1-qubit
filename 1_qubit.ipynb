# %%
# !pip install qiskit qiskit-aer --upgrade
# Out:
# Requirement already satisfied: qiskit in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (2.2.1)
# Requirement already satisfied: qiskit-aer in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (0.17.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (2.2.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (1.15.2)
# Requirement already satisfied: dill>=0.3 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (4.13.0)
# Requirement already satisfied: psutil>=5 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dhiva\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# %%
def run_all_tasks():
    simulator = AerSimulator()

    # Task 1: 1 qubit Hadamard, 100 shots
    qc1 = QuantumCircuit(1, 1)
    qc1.h(0)
    qc1.measure(0, 0)
    job1 = simulator.run(qc1, shots=100)
    counts1 = job1.result().get_counts(qc1)
    print("Task 1 Result (1 qubit, Hadamard, 100 shots):", counts1)

    # Task 2: 2 qubits Hadamard, 100 shots
    qc2 = QuantumCircuit(2, 2)
    qc2.h(0)
    qc2.h(1)
    qc2.measure([0, 1], [0, 1])
    job2 = simulator.run(qc2, shots=100)
    counts2 = job2.result().get_counts(qc2)
    print("Task 2 Result (2 qubits, Hadamard, 100 shots):", counts2)

    # Task 3: 1 qubit X gate, 100 shots
    qc3 = QuantumCircuit(1, 1)
    qc3.x(0)
    qc3.measure(0, 0)
    job3 = simulator.run(qc3, shots=100)
    counts3 = job3.result().get_counts(qc3)
    print("Task 3 Result (1 qubit, X gate, 100 shots):", counts3)

# %%
if __name__ == "__main__":
    run_all_tasks()
# Out:
# Task 1 Result (1 qubit, Hadamard, 100 shots): {'0': 54, '1': 46}
# Task 2 Result (2 qubits, Hadamard, 100 shots): {'11': 19, '01': 25, '10': 24, '00': 32}
# Task 3 Result (1 qubit, X gate, 100 shots): {'1': 100}
